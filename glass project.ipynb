# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("glass identification.csv")

# %%
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')

# %%
file_path=r"glass identification.csv"
df1=pd.read_csv(file_path,header=None,names=['Id number','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type of Glass'])

# %%
df1
# Out:
#      Id number       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  \
# 0            1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1            2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2            3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3            4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4            5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..         ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209        210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210        211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211        212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212        213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213        214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type of Glass
# 0                1
# 1                1
# 2                1
# ...

# %%
df1 = df1.drop('Id number',1)

# %%
df1.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe  Type of Glass
# count  214.000000  214.000000  214.000000     214.000000
# mean     8.956963    0.175047    0.057009       2.780374
# std      1.423153    0.497219    0.097439       2.103739
# ...

# %%
df1.shape
# Out:
# (214, 10)

# %%
print("The dimensions of datasets:",df.shape)
# Out:
# The dimensions of datasets: (213, 11)

# %%
df1.isnull().sum()
# Out:
# RI               0
# Na               0
# Mg               0
# Al               0
# Si               0
# K                0
# Ca               0
# Ba               0
# Fe               0
# Type of Glass    0
# dtype: int64

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
for i  in df1.columns:
    print(df1[i].value_counts())
    print("\n")
# Out:
# 1.51590    3
# 1.51645    3
# 1.52152    3
# 1.51646    2
# 1.51829    2
#           ..
# 1.51818    1
# 1.51783    1
# 1.52410    1
# 1.51869    1
# 1.51588    1
# Name: RI, Length: 178, dtype: int64
#
#
# 13.21    5
# 13.02    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.70    1
# 12.96    1
# 14.04    1
# 13.04    1
# 14.70    1
# Name: Na, Length: 142, dtype: int64
#
#
# 0.00    42
# 3.58     8
# 3.54     8
# 3.48     8
# 3.52     7
#         ..
# 2.88     1
# 0.78     1
# 1.78     1
# 2.24     1
# 2.71     1
# Name: Mg, Length: 94, dtype: int64
#
#
# 1.54    8
# 1.19    6
# 1.29    5
# 1.43    5
# 1.56    5
#        ..
# 2.02    1
# 1.94    1
# 1.64    1
# 1.20    1
# 0.71    1
# Name: Al, Length: 118, dtype: int64
#
#
# 72.99    4
# 73.10    4
# 73.11    4
# 73.28    4
# 72.86    4
#         ..
# 72.14    1
# 73.14    1
# 72.40    1
# 73.44    1
# 73.30    1
# Name: Si, Length: 133, dtype: int64
#
#
# 0.00    30
# 0.57    12
# 0.56    11
# 0.60    11
# 0.58    10
# ...

# %%
df1.dtypes
# Out:
# RI               float64
# Na               float64
# Mg               float64
# Al               float64
# Si               float64
# K                float64
# Ca               float64
# Ba               float64
# Fe               float64
# Type of Glass      int64
# dtype: object

# %%
numerical_col=[]
for i in df1.dtypes.index:
    if df1.dtypes[i]!= "object":
        numerical_col.append(i)
        print("Numerical Columns:",numerical_col)
# Out:
# Numerical Columns: ['RI']
# Numerical Columns: ['RI', 'Na']
# Numerical Columns: ['RI', 'Na', 'Mg']
# Numerical Columns: ['RI', 'Na', 'Mg', 'Al']
# Numerical Columns: ['RI', 'Na', 'Mg', 'Al', 'Si']
# Numerical Columns: ['RI', 'Na', 'Mg', 'Al', 'Si', 'K']
# Numerical Columns: ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca']
# Numerical Columns: ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba']
# Numerical Columns: ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe']
# Numerical Columns: ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type of Glass']

# %%
df1.nunique().to_frame("No.of unique values")
# Out:
#                No.of unique values
# RI                             178
# Na                             142
# Mg                              94
# Al                             118
# Si                             133
# K                               65
# Ca                             143
# Ba                              34
# Fe                              32
# Type of Glass                    6

# %%
df1["Type of Glass"].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
plt.figure(figsize=(12,6))
df1.drop('Type of Glass',axis=1).plot(kind = 'bar', stacked=True,cmap='viridis')
plt.title('Element Composition of Glass samples')
plt.xlabel('Glass Sample ID')
plt.ylabel('Element Concentration')
plt.xticks(rotation=0)
plt.legend(title="Element")
plt.show()

# %%
glass_type_counts= df1['Type of Glass'].value_counts()
plt.figure(figsize=(8,6))
glass_type_counts.plot(kind = 'bar', stacked=True, color='skyblue')
plt.title('Distribution of Glass types')
plt.xlabel('Glass Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
numerical_col =df1.select_dtypes(include=[np.number]).columns.tolist()
plotnumber = 1
plt.figure(figsize=(15,15))
for col in numercal_col:
    if plotnumber<=25 :
        plt.subplot(5,5,plotnumber)
        sns.histlot(df[col],kde=True, color='m')
        plt.xlabel(col,fontsize=12)
        plotnumer+=1  
else:
     break 
            
plt.tight_layout()
plt.show()
# Out:
#   File "<ipython-input-39-b80c7223d312>", line 11
#     break
#     ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# # Checking Outliers

# %%
sns.pairplot(df1,hue = "Type of Glass",palette="Dark2")
plt.show()

# %%
num_numerical_cols = len(numerical_col)
num_rows = 5
num_cols=4
total_subplots = num_rows*num_cols
plt.figure(figsize=(20,16),facecolor="white")
plotnumber = 1
for col in numerical_col:
    if plotnumber<= total_subplots:
    ax=plt.subplot(num_rows, num_cols,plotnumber)
    sns.boxplot(x=df1[col],palette="set2_r",ax=ax)
    plt.xlabel(col, fontsize=15)
    plt.ylabel("")
    plt.xticks(rotation=0,fontsize=10)
    plt.yticks(fontsize=10)
    plotnumber +=1
    plt.tight_layout()
    plt.show()
# Out:
#   File "<ipython-input-43-21a3f47f2bff>", line 9
#     ax=plt.subplot(num_rows, num_cols,plotnumber)
#     ^
# IndentationError: expected an indented block

# %%
columns_of_interest=['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe',]
Q1 = df1[columns_of_interest].quantile(0.25)
Q3= df1 [columns_of_interest].quantile(0.75)
IQR = Q3- Q1

lower_bound=Q1-1.5*IQR
upper_bound = Q3 + 1.5*IQR

outliers= df1[((df1[columns_of_interest]<lower_bound)|(df1[columns_of_interest]>upper_bound)).any(axis=1)]
df2=df1[~((df1[columns_of_interest]<lower_bound)|(df1[columns_of_interest]>upper_bound)).any(axis=1)]
print("DataFrame after removing outliers:")
print(df2)
print("\noutliers removed:")
print(outliers)
# Out:
# DataFrame after removing outliers:
#           RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type of Glass
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0              1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0              1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0              1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0              1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0              1
# ..       ...    ...   ...   ...    ...   ...   ...  ...  ...            ...
# 176  1.51905  14.00  2.39  1.56  72.37  0.00  9.57  0.0  0.0              6
# 177  1.51937  13.79  2.41  1.19  72.76  0.00  9.77  0.0  0.0              6
# 178  1.51829  14.46  2.24  1.62  72.38  0.00  9.26  0.0  0.0              6
# 179  1.51852  14.09  2.19  1.66  72.67  0.00  9.32  0.0  0.0              6
# 181  1.51888  14.99  0.78  1.74  72.50  0.00  9.95  0.0  0.0              6
#
# ...

# %% [markdown]
# # cheking skewness

# %%
df2.skew()
# Out:
# RI               1.052990
# Na               0.843116
# Mg              -3.404660
# Al              -0.100644
# Si              -0.476993
# K               -1.022915
# Ca               0.808200
# Ba               0.000000
# Fe               1.395243
# Type of Glass    2.122805
# dtype: float64

# %%
sns.heatmap(df2.corr(),annot=True)
plt.show()

# %% [markdown]
# # split target features

# %%
x=df2.drop(['Type of Glass'], axis=1)
y=df2["Type of Glass"].apply(lambda y_value:1 if y_value>=5 else 0)
print(y)
print("Feature Dimensions=",x.shape)
print("Label Dimensions",y.shape)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 176    1
# 177    1
# 178    1
# 179    1
# 181    1
# Name: Type of Glass, Length: 136, dtype: int64
# Feature Dimensions= (136, 9)
# Label Dimensions (136,)

# %%
y.value_counts()
# Out:
# 0    129
# 1      7
# Name: Type of Glass, dtype: int64

# %% [markdown]
# # smote

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(k_neighbors=1)
x1,y1=sm.fit_resample(x,y)

# %%
y1.value_counts()
# Out:
# 0    129
# 1    129
# Name: Type of Glass, dtype: int64

# %%
pip install imbalanced-learn
# Out:
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.0.1
#     Uninstalling joblib-1.0.1:
#       Successfully uninstalled joblib-1.0.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.ensemble import RandomForestRegressor,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu=0
maxRs=0
for i in range (1,50):
    x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.30,random_state=i)
    ETR= ExtraTressClassifier(()
    ETR.fit(x_train , y_train)
    pred=ETR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs = i
# Out:
#   File "<ipython-input-7-2806255bef71>", line 9
#     ETR.fit(x_train,  y_train)
#     ^
# SyntaxError: invalid syntax

# %%
print("Best accuracy is",maxAcccu,"at random_state",maxRs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6ca54dee5ec6> in <module>
# ----> 1 print("Best accuracy is",maxAcccu,"at random_state",maxRs)
#
# NameError: name 'maxAcccu' is not defined

# %% [markdown]
# # train test split

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=maxRs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ec677102ed0b> in <module>
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=maxRs)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# # Random ForestClassifier

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
pred_rf= rf.predict(x_test)
accuracy= accuracy_score(y_test,pred_rf)
print("Accuracy:",accuracy)
conf_matrix=confusion_matrix(y_test,pred_rf)
print("Confusion Matrix:")
print(conf_matrix)
report=classification_report(y_test,pred_rf)
print("Classification Report:")
print(report)

# %% [markdown]
# # ExtraTreesClassifier

# %%
ET=RandomForestClassifier()
ET.fit(x_train,y_train)
pred_et= ET.predict(x_test)
accuracy= accuracy_score(y_test,pred_et)
print("Accuracy:",accuracy)
conf_matrix=confusion_matrix(y_test,pred_et)
print("Confusion Matrix:")
print(conf_matrix)
report=classification_report(y_test,pred_et)
print("Classification Report:")
print(report)

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'criterion':['gini','entropy'],
             'random_state':[10,50,1000],
             'max_depth':[0,10,20],
             'n_jobs':[-2,-1,1],
             'n_estimators':[50,100,200,300]}

# %%
GCV=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)

# %%
GCV.best_params_

# %%
Model= ExtraTreesClassifier( criterion="gini", max_depth= 10,n_jobs=-2 , random_state=50,n_estimators = 50 )
Model.fit(x_train, y_train)
pred=Model.predict(x_test)
acc= accuracy_score(y_test,pred)
print(acc*100)

# %%
#SAVING THE MODEL
import joblib
joblib.dump(Model, open(filename,'wb'))

# %%
import pickle 
file="Glass_predict.pkl"
pickle.dump(Model,open(filename,'wb'))

# %% [markdown]
# # predicted the saved model

# %%
load_modelpickle.load(open("Glass_predict.pkl",'rb'))
result= load_model.score(x_test,y_test)
print(result*100)

# %% [markdown]
# # Conclusion

# %%
conclusion=pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion

# %%
x1

# %%
input_data = np.array([[1.51829,14,46,2.24,1.62,72.38,0.00,0.00]])
prediction = Model.predict(input_data)
print("Input Data:",input_data)
print("predicted Insurance Cost:",prediction)

# %%
if prediction ==0:
    print("window Glass")
else:
    print("Non window Glass")
